# %% [markdown]
# # Data Aquisition

# %% [markdown]
# ## Loading Data and Libraries

# %%
import pycep_correios as pycep
import geocoder
import pandas as pd
import csv
import json
import os

DATAPATH = '../data/'

# %%
df_ceps = pd.read_csv(os.path.join(DATAPATH, 'raw', 'preprocessed', 'CEPs.csv'), header=None)
df_ceps = df_ceps[0]

# %% [markdown]
# ## Informações básicas

# %% [markdown]
# ### Amostra

# %%
df_ceps.sample(5)
# Out:
# 14056    66816249
# 18038     9060000
# 10649    31578230
# 20524    26170060
# 368      69908550
# Name: 0, dtype: int64

# %% [markdown]
# ### Shape dos dados

# %%
df_ceps.shape
# Out:
# (1184,)

# %% [markdown]
# ## Pré-processamento

# %% [markdown]
# Os CEPs estão no formato Int, com isso o 0 inicial é descartado, o que não é verdade para a lógica real do CEP.

# %%
df_ceps.apply(lambda x: len(str(x))).value_counts()
# Out:
# 8    1061
# 7     123
# Name: 0, dtype: int64

# %% [markdown]
# Transformação para String e adição do zero à esquerda, quando aplicável.

# %%
df_ceps = df_ceps.astype(str).apply(lambda x: x.zfill(8))

# %%
df_ceps.apply(lambda x: len(str(x))).value_counts()
# Out:
# 8    1184
# Name: 0, dtype: int64

# %% [markdown]
# ## Obter localização (lat, long) a partir do CEP

# %% [markdown]
# ### Consultar Endereço a partir do CEP através da API dos Correios

# %%
def get_address(cep):
    address = None
    try:
        address = pycep.consultar_cep(cep)
    except:
        pass
    return address

# %%
cep_address_map = {}

# %%
ceps = df_ceps.to_list()

# %%
i = 0
for cep in ceps:
    if i % 100 == 0: print(i)
    cep_address_map[cep] = get_address(cep)
    i += 1
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100

# %%
cep_address_map_2 = {}
for i in cep_address_map:
    cep = cep_address_map[i]
    if cep != None:
        cep_address_map_2[i] = cep

# %%
df_address = pd.DataFrame(cep_address_map_2.values(), index=cep_address_map_2.keys())

# %%
df_address.head()
# Out:
#                               bairro       cep          cidade  \
# 60730265             Parque São José  60730265       Fortaleza
# 53605000            Campina de Feira  53605000        Igarassu
# 18700970
# 27267112  Duzentos e Quarenta e Nove  27267112   Volta Redonda
# 23076380                Campo Grande  23076380  Rio de Janeiro
#
#                                     complemento2  \
# 60730265                   - de 1350/1351 ao fim
# 53605000  - do km 39,010 ao km 40,004 - lado par
# 18700970
# 27267112               - de 760 a 830 - lado par
# 23076380                                    None
#
#                                        end  uf unidadesPostagem
# 60730265          Rua Antônio Costa Mendes  CE               []
# 53605000  Avenida Alfredo Bandeira de Melo  PE               []
# 18700970                                                     []
# 27267112                    Avenida Europa  RJ               []
# 23076380                    Rua Taufik Dib  RJ               []

# %%
df_address.to_csv('../data/raw/address_novo.csv')

# %% [markdown]
# ### Consultar a localização a partir do endereço através do Open Street Map

# %%
cep_location_map = {}

j = 0
for i, row in df_address.iterrows():
    if j % 100 == 0: print(j)
    
    cep_location_map[i] = {'lng': None, 'lat': None}
    
    if row['end'] and row['uf']:
    
        geo = geocoder.osm(row['end'] + ', ' + row['uf'] + ', Brasil')

        if geo.ok:
            cep_location_map[i] = {'lng': geo.osm['x'], 'lat': geo.osm['y']}
    j += 1
# Out:
# 0
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+
2C+MG%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Padre+Manuel+da+N%C3%B3brega%2C+ES%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Augusto+Mallon%2C+SC%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+DJ+-+042%2C+SC%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Quadrangular%2C+SC%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Ant%C3%B4nio+Pinto%2C+RJ%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Prot%C3%A1sio+Alves%2C+RS%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Cec%C3%ADlia+de+Souza%2C+MG%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+do+Cruzeiro+8%2C+MG%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Padre+Dami%C3%A3o%2C+MG%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Expedicion%C3%A1rio+Ant%C3%B4nio+Coelho+da+Silveira%2C+MG%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Coronel+Francisco+Silva%2C+AL%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Doutor+Agenor+de+Carvalho%2C+RO%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Vit%C3%B3ria%2C+GO%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Conselheiro+Saraiva%2C+SP%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Quadra+604+Sul+Alameda+2%2C+TO%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Avenida+A%2C+CE%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Juca+Parente%2C+CE%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+C%C3%B4nego+Santana%2C+MG%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Travessa+Amigo+Leal%2C+SP%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Ros%C3%A2ngela%2C+SP%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Figueiredo+Pimentel%2C+RJ%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Carlos%2C+RJ%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Fernando+Abbott%2C+RS%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Desembargador+Motta%2C+PR%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Jos%C3%A9+Toselli%2C+SP%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+do+Lavradio%2C+RJ%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Manoel+Pereira+Barbosa%2C+SP%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Onze+de+Junho%2C+RS%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Benjamin+Constant%2C+RS%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Travessa+Lusitana%2C+RS%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Alegrete%2C+RS%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Avenida+Jos%C3%A9+Natal+Ferreira%2C+SP%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Francisco+Ivan+Teixeira%2C+SP%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Bacharel+Irenaldo+de+Albuquerque+Chaves%2C+PB%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Andr%C3%A9+Chaves%2C+CE%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+da+Base+A%C3%A9rea%2C+GO%2C+Brasil&format=jsonv2&addressdetails=1&limit=1
# INFO:geocoder.base:Requested https://nominatim.openstreetmap.org/search?q=Rua+Ant%C3%B4nio+Simi%C3%A3o+da+Costa%2C+MG%2C+Brasil&format=jsonv2&addressdetails=1&limit=1

# %%
df_locations = pd.DataFrame(cep_location_map.values(), index=cep_location_map.keys())

# %%
df_locations.shape
# Out:
# (872, 2)

# %%
df_locations['lat'].isnull().sum() / df_locations.shape[0]
# Out:
# 0.22362385321100917

# %%
df_locations.to_csv('../data/raw/locations.csv')

# %% [markdown]
# ## Juntar informações

# %%
data = pd.merge(df_locations, df_address, left_index=True, right_index=True, how='inner')

# %%
data.head()
# Out:
#                 lat        lng                      bairro       cep  \
# 60730265  -3.790178 -38.583916             Parque São José  60730265
# 53605000        NaN        NaN            Campina de Feira  53605000
# 18700970        NaN        NaN
# 27267112 -22.531716 -44.126833  Duzentos e Quarenta e Nove  27267112
# 23076380 -22.877733 -43.576327                Campo Grande  23076380
#
#                   cidade                            complemento2  \
# 60730265       Fortaleza                   - de 1350/1351 ao fim
# 53605000        Igarassu  - do km 39,010 ao km 40,004 - lado par
# 18700970
# 27267112   Volta Redonda               - de 760 a 830 - lado par
# 23076380  Rio de Janeiro                                    None
#
#                                        end  uf unidadesPostagem
# 60730265          Rua Antônio Costa Mendes  CE               []
# 53605000  Avenida Alfredo Bandeira de Melo  PE               []
# 18700970                                                     []
# 27267112                    Avenida Europa  RJ               []
# 23076380                    Rua Taufik Dib  RJ               []

# %% [markdown]
# ## Exportar dados

# %%
data.to_csv('../data/external/cep_location.csv')
